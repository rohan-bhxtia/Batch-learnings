# %%
import os
os.getcwd()
# Out:
# '/Users/rohan/ZZZZ/ai/I:O/O'

# %%
os.listdir()
# Out:
# ['1operations.ipynb', '2modes.ipynb', 'sample.txt']

# %%
f = open("sample.txt","r")
data = f.read()
print(data)
# Out:
# jai kara shera wali da

# %%
f.close() ##must be closed in a code when its open

# %% [markdown]
# ## now what if we want to read only 1 line ?

# %%
# think of text as pointer ... 1st line first pointer , 2nd line 2nd pointer
f = open("sample.txt","r") 
data = f.readline()
print(data)

data = f.readline() # doosri baar likha h taaki second line print ho ske 
print(data)

f.close()
# Out:
# jai kara shera wali da

# %% [markdown]
#  ## overwrite

# %%
f= open("sample.txt","w")
f.write("jai kara shera wali da")
f.close()


# this will not print what we changed but change the file entirely in location ( open txt file to see)...

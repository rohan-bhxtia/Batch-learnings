# %%
print("hello ji")
# Out:
# hello ji

# %%
a = str(input("enter ur name"))
b = int(input("enter ur age"))
print(f"hello {a} , you are {b} years old !")
# Out:
# hello rohan , you are 23 years old !

# %%
a = int(input("enter number a: "))
b = int(input("enter number b: "))
print(a+b)
print(a-b)
print(a*b)
print(a/b)
# Out:
# 12
# 8
# 20
# 5.0

# %%
a = int(input("enter int number a "))
b = int(input("enter int number b "))
c = float(input("enter a float number "))

d = float(a)+ float(b)+float (c)

print(f"a is {a}")
print(f"b is {b}")
print(f"c is {c}")


print(f"average is {d/3}")
# Out:
# a is 2
# b is 4
# c is 2.4
# average is 2.8000000000000003

# %%
a = str(input("enter a str number"))

print(int(a), type(int(a)))
print(float(a), type (float(a)))

print(str(a), type(str(a)))
# Out:
# 23 <class 'int'>
# 23.0 <class 'float'>
# 23 <class 'str'>

# %%
a = int(input("enter number a : "))
b = int(input("enter number b : "))

temp = None
print(f"real {a,b}")
temp = a 
a = b 
b = temp 

print(f"swap {a,b}")
# Out:
# real (2, 3)
# swap (3, 2)

# %%
r = float(input("enter radius"))
pi = 3.14

print(f"area of circle is {pi*r*r}")
# Out:
# area of circle is 12.56

# %%
p = int(input("enter amount: "))
r = float(input("enter rate of interset: "))
t = float(input("enter time in years: "))

SI = float(p*r*t)/100
print(f"principle amount is: {p}rs")
print(f"rate of interset is: {r}%")
print(f"time is: {t}yrs")
print(f"interset is : {SI}")
print(f"total amount after matuyre is: {SI + p}")
# Out:
# principle amount is: 34234rs
# rate of interset is: 2343243.0%
# time is: 2423423.0yrs
# interset is : 1944035538883306.2
# total amount after matuyre is: 1944035538917540.2

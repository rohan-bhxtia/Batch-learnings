# %%
print("hello world")
# Out:
# hello world

# %%
salary = float(input("Enter your salary: "))

if salary < 30000:
    tax_rate = 5
elif salary <= 70000:
    tax_rate = 15
else:
    tax_rate = 25
tax_amount = salary * tax_rate / 100
print(f"Salary: {salary}")
print(f"Tax Rate: {tax_rate}%")
print(f"Tax Amount: {tax_amount}")
# Out:
# Salary: 40000.0
# Tax Rate: 15%
# Tax Amount: 6000.0

# %%
a = int(input("enter number a : "))
b = int(input("enter b: "))

for i in range (a,b+1):
    if i%2 == 0 :
        print(i)
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
## retuen digits
def numbers(a):
    while a > 0:
        last_digit = a % 10
        print(last_digit)
        a = a // 10

a = int(input("Enter a number: "))
numbers(a)
# Out:
# 3
# 2

# %%
## sum of digits
def numbers(a):
  sum = 0
  while a>0:
    last_digit = a%10
    sum += last_digit
    a = a//10
  print(sum)

a = int(input("enter a : "))

numbers(a)
# Out:
# 9

# %%
#count of digits 

def count(a):
    count = 0
    while a >0:
        last_digit = a//10
        count += 1
        a = last_digit
    return count 

a = int(input("enter a : "))
count(a)
# Out:
# 2

# %%
# numbers from 1-100 which are divisible by both 3 & 5


def divisible(a):
    while 100>a>1:
        if a % 3 == 0 and a % 5 == 0:
            print(a)
        a += 1   # VERY IMPORTANT




a = int(input("enter a : "))
divisible(a)
# Out:
# 30
# 45
# 60
# 75
# 90

# %%
while True:
    a = input("enter a: ")
    if a == "Quit" or a == "quit":
       break   
    a = int(a) 
    if a>0:
       print(f"{a} is +ve")
    elif a<0:
       print(f"{a} is -ve")  
    else :
       print("its a 0 u dumbass")
# Out:
# its a 0 u dumbass
# 3 is +ve
# -23 is -ve

# %%
secret = 7   # secret number decided by you

while True:
    guess = int(input("Guess the number: "))

    if guess > secret:
        print("Too high")
    elif guess < secret:
        print("Too low")
    else:
        print("Correct!")
        break
# Out:
# Too low
# Too low
# Too low
# Too high
# Too low
# Too low
# Too high
# Correct!

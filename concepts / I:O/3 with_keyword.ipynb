# %% [markdown]
# ###
# ## in previous modules we explicitly closed the operation by f.close()
#  # but here we dont need to do that anymore with " with_keyword"

# %%
with open("sample.txt","r") as f:
    data = f.read()
    print(data)
# Out:
# hehe 123appended text

# %%
# and similarly other operations we can perform

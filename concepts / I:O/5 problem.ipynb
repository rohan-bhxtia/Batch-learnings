# %%
# we need to find the word "python" in the text "sample.txt"
#so first we need to create sample.txt

with open("sample.txt","w+") as f :
    f.write("im best in this world \nim learning ML \nlearning python ")
    f.seek(0)
    data = f.read()
    print(data)
# Out:
# im best in this world
# im learning ML
# learning python

# %%
# so now we need to fine the word python .. in which line it is present

# %%
data = True
with open("sample.txt","r") as f :
    while data:
        data = f.readline()
        if ("python" in data):
            print("word found")
            break
        print(data)
# Out:
# im best in this world
#
# im learning ML
#
# word found

# %%
with open("sample.txt","r") as f :
    print(f.read())
# Out:
# im best in this world
# im learning ML
# learning python
# burning my receptors

# %%
data = True
line = 1
word = "receptor"
with open("sample.txt","r") as f:
    while data :
        data = f.readline()
        if (word in data):
            print(f"{word} is found in line:{line}")
            break
        print(data) 
        line+=1
# Out:
# im best in this world
#
# im learning ML
#
# learning python
#
# receptor is found in line:4

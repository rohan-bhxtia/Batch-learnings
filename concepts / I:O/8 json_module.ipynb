# %%
print("hello world")
# Out:
# hello world

# %%
# so json module is used to jump between json formats and python languge ...
# as data is stored in JSON format due to its lowest storage capabilities ..

# %% [markdown]
# ### there are 2 types :
# #### 1. Json.loads() {for converting json to python}.    this "s" in loads is for strong values
# #### 2. Json.dumps(){ for python to json}

# %% [markdown]
# #### 1. JSON.dump().    { no "s" for json or python files}
# #### 2.json.load()

# %%
import json
with open("data.json","r") as f :
    py_str = json.load(f)
    print (py_str)
    print (type(py_str))
# Out:
# {'id': 1, 'name': 'Rohan', 'role': 'AI Student', 'skills': ['Python', 'Machine Learning', 'Deep Learning'], 'active': True}
# <class 'dict'>

# %%
### below is python formatted dictionary to convert in json file 
student = {
    "id": 101,
    "name": "Rohan",
    "department": "AI & Data Science",
    "year": 2,
    "cgpa": 7.1,
    "skills": [
        "Python",
        "Machine Learning",
        "Deep Learning",
        "Git"
    ],
    "projects": {
        "major": "CortX AI Assistant",
        "minor": ["Housing Price Prediction", "Sales Analysis"]
    },
    "active": True,
    "graduating": False
}

json_str = json.dumps(student)
print(json_str)
# Out:
# {"id": 101, "name": "Rohan", "department": "AI & Data Science", "year": 2, "cgpa": 7.1, "skills": ["Python", "Machine Learning", "Deep Learning", "Git"], "projects": {"major": "CortX AI Assistant", "minor": ["Housing Price Prediction", "Sales Analysis"]}, "active": true, "graduating": false}

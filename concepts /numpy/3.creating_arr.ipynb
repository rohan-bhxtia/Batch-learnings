# %%
import numpy as np

# %%
arr1 = np.array([1,2,3,4,5])
print(arr1,type(arr1),arr1.shape)
# Out:
# [1 2 3 4 5] <class 'numpy.ndarray'> (5,)

# %%
arr2 = np.array([6,7,8,9,10,"prime"])
mat = np.array([[1,2,3],[4,5,6],[8,9,10]])
print(arr2)
print(mat)
# Out:
# ['6' '7' '8' '9' '10' 'prime']
# [[ 1  2  3]
#  [ 4  5  6]
#  [ 8  9 10]]
